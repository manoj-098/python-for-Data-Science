# %% [markdown]
# <a href="https://colab.research.google.com/github/manoj-raghav/python/blob/main/Untitled48.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame({
    'NAME':['RAM','SAM','SIVA','JOSEPH','JACKLIN','RAHMAN'],
    'AGE':[10,39,73,49,89,25],
    'CALORIE BURNT':[12.4,45.3,34.8,23.3,56.2,26.5],
    'WEIGHT REDUCED':[1,9,2,3,4,7],
    'AMOUNT SPENT':[10000,21000,32909,84390,23900,3870]
    })
df
# Out:
#       NAME  AGE  CALORIE BURNT  WEIGHT REDUCED  AMOUNT SPENT
# 0      RAM   10           12.4               1         10000
# 1      SAM   39           45.3               9         21000
# 2     SIVA   73           34.8               2         32909
# 3   JOSEPH   49           23.3               3         84390
# 4  JACKLIN   89           56.2               4         23900
# 5   RAHMAN   25           26.5               7          3870

# %%
df.info
# Out:
# <bound method DataFrame.info of       NAME  AGE  CALORIE BURNT  WEIGHT REDUCED  AMOUNT SPENT
# 0      RAM   10           12.4               1         10000
# 1      SAM   39           45.3               9         21000
# 2     SIVA   73           34.8               2         32909
# 3   JOSEPH   49           23.3               3         84390
# 4  JACKLIN   89           56.2               4         23900
# 5   RAHMAN   25           26.5               7          3870>

# %%
df.shape
# Out:
# (6, 5)

# %%
columns=df.shape[1]
columns
# Out:
# 5

# %%
rows=df.shape[0]
rows
# Out:
# 6

# %%
df['AMOUNT SPENT']='NILL'
df
# Out:
#      NAME  AGE  CALORIE BURNT  WEIGHT REDUCED AMOUNT SPENT
# 0  PERSON   10           12.4               1         NILL
# 1  PERSON   39           45.3               9         NILL
# 2  PERSON   73           34.8               2         NILL
# 3  PERSON   49           23.3               3         NILL
# 4  PERSON   89           56.2               4         NILL
# 5  PERSON   25           26.5               7         NILL

# %%
df.rename(columns={'AGE':'DATE'})
# Out:
#      NAME  DATE  CALORIE BURNT  WEIGHT REDUCED AMOUNT SPENT
# 0  PERSON    10           12.4               1         NILL
# 1  PERSON    39           45.3               9         NILL
# 2  PERSON    73           34.8               2         NILL
# 3  PERSON    49           23.3               3         NILL
# 4  PERSON    89           56.2               4         NILL
# 5  PERSON    25           26.5               7         NILL

# %%
df.loc[:3]
# Out:
#      NAME  AGE  CALORIE BURNT  WEIGHT REDUCED AMOUNT SPENT
# 0  PERSON   10           12.4               1         NILL
# 1  PERSON   39           45.3               9         NILL
# 2  PERSON   73           34.8               2         NILL
# 3  PERSON   49           23.3               3         NILL

# %%
df.iloc[1:3]
# Out:
#      NAME  AGE  CALORIE BURNT  WEIGHT REDUCED AMOUNT SPENT
# 1  PERSON   39           45.3               9         NILL
# 2  PERSON   73           34.8               2         NILL

# %%
df.iloc[1,3]
# Out:
# 9

# %%
df.iloc[0:3,[0,1]]
# Out:
#      NAME  AGE
# 0  PERSON   10
# 1  PERSON   39
# 2  PERSON   73
